# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme()

# %%
df = pd.read_csv("D:/Satellites/28GHz/data/slopes.csv")

# %%
R_s = df["R_s"]

# %%
R_b = df["R_b"]

# %%
slope = df["slope"]

# %%
intercept = df["intercept"]

# %%
x_1 = R_s
x_2 = np.square(R_s)
x_3 = R_b
x_4 = np.square(R_b)

# %%
X = np.zeros((4, R_s.size))

# %%
X[0] = x_1
X[1] = x_2
X[2] = x_3
X[3] = x_4

X = X.T

# %%
y_1 = slope
y_2 = intercept

# %%
from sklearn.linear_model import LinearRegression

# %%
reg_1 = LinearRegression().fit(X, y_1)
print(reg_1.intercept_, reg_1.coef_ )
# Out:
# 2.2137349345737456 [-2.63886260e-03  2.14161295e-06 -5.13689179e-04  3.11348350e-07]

# %%
reg_2 = LinearRegression().fit(X, y_2)
print(reg_2.intercept_, reg_2.coef_ )
# Out:
# 0.11129812544396277 [ 6.78146840e-05 -5.92390132e-08  3.02592501e-05 -2.02303562e-08]

# %%
def func_surf(x, y, coef, interc):
    X = [x, x*x, y, y*y]
    return coef@X + interc

# %%
f_1 = func_surf(x_1, x_3, reg_1.coef_, reg_1.intercept_)
f_2 = func_surf(x_1, x_3, reg_2.coef_, reg_2.intercept_)

# %%
ax = plt.axes(projection='3d')
# Data for a three-dimensional line
zline = np.linspace(1, 2, 1000)
xline = np.sin(zline)
yline = np.cos(zline)
ax.plot3D(xline, yline, zline, 'gray')
# Data for three-dimensional scattered points
zdata = 15 * np.random.random(100)
xdata = np.sin(zdata) + 0.1 * np.random.randn(100)
ydata = np.cos(zdata) + 0.1 * np.random.randn(100)
ax.scatter3D(x_1, x_3, f_1, s=1)
ax.scatter3D(x_1, x_3, slope, s=1)
plt.xlabel("R_s")
plt.ylabel("R_b")
# Out:
# Text(0.5, 0, 'R_b')

# %%
ax = plt.axes(projection='3d')
# Data for a three-dimensional line
zline = np.linspace(0.1, 0.16, 1000)
xline = np.sin(zline)
yline = np.cos(zline)
ax.plot3D(xline, yline, zline, 'gray')
# Data for three-dimensional scattered points
zdata = 15 * np.random.random(100)
xdata = np.sin(zdata) + 0.1 * np.random.randn(100)
ydata = np.cos(zdata) + 0.1 * np.random.randn(100)
ax.scatter3D(x_1, x_3, f_2, s=1)
ax.scatter3D(x_1, x_3, intercept, s=1)
plt.xlabel("R_s")
plt.ylabel("R_b")
# Out:
# Text(0.5, 0, 'R_b')

# %%
C_1 = np.array([reg_1.coef_[0], reg_1.coef_[1], reg_1.coef_[2], reg_1.coef_[3], reg_1.intercept_])
C_2 = np.array([reg_2.coef_[0], reg_2.coef_[1], reg_2.coef_[2], reg_2.coef_[3], reg_2.intercept_])

# %%
np.savetxt('D:/Satellites/28GHz/data/slope_fit.csv', C_1)
np.savetxt('D:/Satellites/28GHz/data/intercept_fit.csv', C_2)
